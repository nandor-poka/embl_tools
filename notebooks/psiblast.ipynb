# %%
import core.psiblast_ui
# Out:
# AppLayout(children=(Label(value='EMBL-Tools Template webservice', layout=Layout(grid_area='header')), HBox(chi…
# Output(layout=Layout(border='1px solid black'))
